# %%
# !wget -c https://www.collinsdictionary.com/images/thumb/receipt_573065707_250.jpg -O receipt.jpg
# Out:
# --2020-06-30 05:48:51--  https://www.collinsdictionary.com/images/thumb/receipt_573065707_250.jpg
# Resolving www.collinsdictionary.com (www.collinsdictionary.com)... 104.20.66.159, 104.20.67.159, 2606:4700:10::6814:429f, ...
# Connecting to www.collinsdictionary.com (www.collinsdictionary.com)|104.20.66.159|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5251 (5.1K) [image/jpeg]
# Saving to: ‘receipt.jpg’
#
# receipt.jpg         100%[===================>]   5.13K  --.-KB/s    in 0s
#
# 2020-06-30 05:48:59 (32.4 MB/s) - ‘receipt.jpg’ saved [5251/5251]

# %%
from skimage.filters import threshold_local
import numpy as np
import cv2
import imutils
from google.colab.patches import cv2_imshow

# %%
image = cv2.imread('receipt.jpg')

# %%
image.shape
# Out:
# (252, 250, 3)

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=250x252 at 0x7FF6B2B12B00>

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
gray = cv2.GaussianBlur(gray, (3, 3), 0)
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=250x252 at 0x7FF6B2B122E8>

# %%
edged = cv2.Canny(gray, 20, 50)
cv2_imshow(edged)
# Out:
# <PIL.Image.Image image mode=L size=250x252 at 0x7FF6B2B12588>
